# %%
print("hello world")
# Out:
# hello world

# %%
a='6'

# %%
a
# Out:
# '6'

# %%
type(a)
# Out:
# str

# %%
c=int(a)

# %%
c
# Out:
# 6

# %%
type(c)
# Out:
# int

# %%
z='3'

# %%
type(z)
# Out:
# str

# %%
y=int(z)

# %%
y
# Out:
# 3

# %%
type(y)
# Out:
# int

# %%
a="hello world"

# %%
print(a)
# Out:
# hello world

# %%
a=1

# %%
a
# Out:
# 1

# %%
b=2.2

# %%
b
# Out:
# 2.2

# %%
c="tabrase"

# %%
c
# Out:
# 'tabrase'

# %%
c=("apple")

# %%
c
# Out:
# 'apple'

# %%
d= 4j

# %%
d
# Out:
# 4j

# %%
type(d)
# Out:
# complex

# %%
z=('tab')

# %%
z
# Out:
# 'tab'

# %%
type(z)
# Out:
# str

# %%
a='1'

# %%
a
# Out:
# '1'

# %%
type(a)
# Out:
# str

# %%
a=int(a)

# %%
a
# Out:
# 1

# %%
type(a)
# Out:
# int

# %% [markdown]
# ##arithmetic operator
# ##

# %%
a=3

# %%
b=3

# %%
a+b
# Out:
# 6

# %%
a-b
# Out:
# 0

# %%
a=4

# %%
b=5

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a>=b
# Out:
# False

# %%
a>=b
# Out:
# False

# %%
x=5

# %%
x>3 and x<10
# Out:
# True

# %%
x>3 or x<4
# Out:
# True

# %%
not(x>3 and x<10)
# Out:
# False

# %%
z=['apple','banana']
print(z)
# Out:
# ['apple', 'banana']

# %%
print('apple'   in z)
# Out:
# True

# %%
print('apple' in z)
# Out:
# True

# %%
'apple'==z
# Out:
# False

# %%
t=7

# %%
t+=1

# %%
t
# Out:
# 8

# %%
a=2

# %%
b=3

# %%
a<b and b>a
# Out:
# True

# %%
a<b or b>a
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
z=[1,2,3,4]

# %%
z
# Out:
# [1, 2, 3, 4]

# %%
print(1  not in z)
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
print("helloworld")
# Out:
# helloworld

# %% [markdown]
# ## DATA STRUCTURES ##
# - LIST
# - TUPLE
# - SET
# - DICT

# %% [markdown]
# #**DATA**

# %% [markdown]
# ## **LIST**

# %%
x =['hyder','hussain','khan',3,3.4,True]

# %%
x
# Out:
# ['hyder', 'hussain', 'khan', 3, 3.4, True]

# %%
len(x)
# Out:
# 6

# %%
type(x)
# Out:
# list

# %%
y=list(('hyder','hussain','khan',3,3.4,True))

# %%
y
# Out:
# ['hyder', 'hussain', 'khan', 3, 3.4, True]

# %%
len(y)
# Out:
# 6

# %%
z=list[('apple','banana','cherry')]

# %%
z
# Out:
# list['apple', 'banana', 'cherry']

# %%
z[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 z[0:3]
#
# TypeError: list['apple', 'banana', 'cherry'] is not a generic class

# %%
x[0]
# Out:
# 'hyder'

# %%
x[0:3]
# Out:
# ['hyder', 'hussain', 'khan']

# %%
x[:3]
# Out:
# ['hyder', 'hussain', 'khan']

# %%
x[3]=4

# %%
x
# Out:
# ['hyder', 'hussain', 'khan', 4, 3.4, True]

# %%
x[3]='jaweed'

# %%
x
# Out:
# ['hyder', 'hussain', 'khan', 'jaweed', 3.4, True]

# %%
x.append(' tabrse khan')

# %%
x
# Out:
# ['hyder', 'hussain', 'khan', 'jaweed', 3.4, True, ' tabrse khan']

# %%
x
# Out:
# ['hyder',
#  'hussain',
#  'shareef',
#  'shareef',
#  'shareef',
#  'shareef',
#  'shareef',
#  'khan',
#  'jaweed',
#  3.4,
#  True,
#  ' tabrse khan']

# %%
x
# Out:
# ['hyder',
#  'hussain',
#  'shareef',
#  'shareef',
#  'shareef',
#  'shareef',
#  'shareef',
#  'khan',
#  'jaweed',
#  3.4,
#  True,
#  ' tabrse khan']

# %%
x =['hyder','hussain','khan',3,3.4,True]

# %%
x
# Out:
# ['hyder', 'hussain', 'khan', 3, 3.4, True]

# %%
x.append(('hello'))

# %%
x
# Out:
# ['hyder', 'hussain', 'khan', 3, 3.4, True, 'hello']

# %%
x.insert(2,'kadhar')

# %%
x
# Out:
# ['hyder', 'hussain', 'kadhar', 'kadhar', 'khan', 3, 3.4, True, 'hello']

# %%
x.remove('hello')

# %%
x
# Out:
# ['hyder', 'hussain', 'kadhar', 'kadhar', 'khan', 3, 3.4, True]

# %%
x.pop(2)
# Out:
# 'kadhar'

# %%
x
# Out:
# ['hyder', 'kadhar', 'khan', 3, 3.4, True]

# %%
x.pop(0)
# Out:
# 'hyder'

# %%
x
# Out:
# ['kadhar', 'khan', 3, 3.4, True]

# %%
x.remove(True)

# %%
x
# Out:
# ['kadhar', 'khan', 3, 3.4]

# %%
x.clear()

# %%
x
# Out:
# []

# %%
x[::-1]
# Out:
# []

# %%
z=[4,7,3,8,2,9]

# %%
z
# Out:
# [4, 7, 3, 8, 2, 9]

# %%
z.sort()

# %%
z
# Out:
# [2, 3, 4, 7, 8, 9]

# %%
z.sort(reverse=True)

# %%
z
# Out:
# [9, 8, 7, 4, 3, 2]

# %%
x=["hyder","sultan","taimur",3,4.5,True,1j]

# %%
x
# Out:
# ['hyder', 'sultan', 'taimur', 3, 4.5, True, 1j]

# %%
x[0]
# Out:
# 'hyder'

# %%
x[2]
# Out:
# 'taimur'

# %%
x[:]
# Out:
# ['hyder', 'sultan', 'taimur', 3, 4.5, True, 1j]

# %%
x[0:]
# Out:
# ['hyder', 'sultan', 'taimur', 3, 4.5, True, 1j]

# %%
x[0:2]
# Out:
# ['hyder', 'sultan']

# %%
x[3:]
# Out:
# [3, 4.5, True, 1j]

# %%
x[0]='jaweed'

# %%
x
# Out:
# ['jaweed', 'sultan', 'taimur', 3, 4.5, True, 1j]

# %%
x.append('khan')

# %%
x
# Out:
# ['jaweed', 'sultan', 'taimur', 3, 4.5, True, 1j, 'khan']

# %%
x.insert(2,'tabrase')

# %%
x
# Out:
# ['jaweed', 'sultan', 'tabrase', 'taimur', 3, 4.5, True, 1j, 'khan']

# %%
x[-1]
# Out:
# 'khan'

# %%
x.pop()
# Out:
# 'khan'

# %%
x
# Out:
# ['jaweed', 'sultan', 'tabrase', 'taimur', 3, 4.5, True, 1j]

# %%
x[::-1]
# Out:
# [1j, True, 4.5, 3, 'taimur', 'tabrase', 'sultan', 'jaweed']

# %%
x.pop(2)
# Out:
# 'tabrase'

# %%
x
# Out:
# ['jaweed', 'sultan', 'taimur', 3, 4.5, True, 1j]

# %%
x.pop(0)
# Out:
# 'jaweed'

# %%
x
# Out:
# ['sultan', 'taimur', 3, 4.5, True, 1j]

# %%
x.remove('sultan')

# %%
x
# Out:
# ['taimur', 3, 4.5, True, 1j]

# %%
x.append('khan')

# %%
x
# Out:
# ['taimur', 3, 4.5, True, 1j, 'khan']

# %%
x.insert(2,'tabrase')

# %%
x
# Out:
# ['taimur', 3, 'tabrase', 4.5, True, 1j, 'khan']

# %%
x.pop(1)
# Out:
# 3

# %%
x
# Out:
# ['taimur', 'tabrase', 4.5, True, 1j, 'khan']

# %%
x=[1,2,3,4,6.9,5]

# %%
y=[7,8,9,0,5.6]

# %%
x+y
# Out:
# [1, 2, 3, 4, 6.9, 5, 7, 8, 9, 0, 5.6]

# %%
x.sort()

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6.9]

# %%
x.sort(reverse=True)

# %%
x
# Out:
# [6.9, 5, 4, 3, 2, 1]

# %% [markdown]
# ## **TUPLE**
# - IMMUTABLE

# %%
t=(1,2,3,4,5,'hyder','hussain',3.4,True)

# %%
t
# Out:
# (1, 2, 3, 4, 5, 'hyder', 'hussain', 3.4, True)

# %%
type(t)
# Out:
# tuple

# %%
s={1,2,3,4,5,'hyder','hussain',3.4,True}
